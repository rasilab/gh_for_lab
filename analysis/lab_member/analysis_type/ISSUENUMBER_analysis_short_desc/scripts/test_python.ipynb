# %% [markdown]
# # Sample Python Notebook

# %%
import pandas as pd
import matplotlib.pyplot as plt

# %%
iris = pd.read_csv('https://raw.githubusercontent.com/mwaskom/seaborn-data/master/iris.csv')

# %%
iris.plot(kind='hist', y='sepal_length', bins=20);
